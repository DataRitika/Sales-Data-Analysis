# %%
# Imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.io as pio

# %%
# Set Plotly default template and Seaborn style for a deep blue theme
pio.templates.default = "plotly_white"
sns.set_theme(style="whitegrid", palette="deep")
custom_palette = ["#041E42", "#1B365D", "#4B6FA5", "#7DA0CA", "#A7C7E7"]

# %%
# Load Data
df = pd.read_csv('/content/Sales_Data.csv', encoding='unicode_escape')

# %%
#Check Number of rows and Columns
df.shape
# Out:
# (11257, 13)

# %%
#To see the imported data
df.head(5)
# Out:
#      User_ID Cust_name Product_ID   Age Age Group  Gender           State  \
# 0  1002903.0      Anvi  P00125942  27.0     26-35  Female     Maharashtra
# 1  1000732.0    Shanta  P00110942  34.0     26-35  Female  Andhra Pradesh
# 2  1001990.0   Sheetal  P00118542  16.0      0-17  Female   Uttar Pradesh
# 3  1001425.0  Virendra  P00237842  16.0      0-17       M       Karnataka
# 4  1000588.0    Vishal  P00057942  28.0     26-35       M         Gujarat
#
#       Zone  Zipcode       Profession Product_Category  Orders   Amount
# 0     West      NaN       Healthcare          Sports      4.0  20500.0
# 1    South      NaN             Govt          Sports      2.0  25360.0
# 2  Central      NaN       Automobile           Health     4.0  29350.0
# 3    South      NaN     Construction         Clothing     6.0  23500.0
# 4     West      NaN  Food Processing      Electronics     4.0  23870.0

# %%
#Field details and Data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11257 entries, 0 to 11256
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11245 non-null  float64
#  1   Cust_name         11245 non-null  object
#  2   Product_ID        11245 non-null  object
#  3   Age               11245 non-null  float64
#  4   Age Group         11245 non-null  object
#  5   Gender            11245 non-null  object
#  6   State             11245 non-null  object
#  7   Zone              11245 non-null  object
#  8   Zipcode           0 non-null      float64
#  9   Profession        11245 non-null  object
#  10  Product_Category  11245 non-null  object
#  11  Orders            11245 non-null  float64
#  12  Amount            11245 non-null  float64
# dtypes: float64(5), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# Data Cleaning

# %%
#Deleting blank column
df.drop(['Zipcode'], axis=1, inplace=True)

# %%
#List of Columns Available
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Age', 'Age Group', 'Gender',
#        'State', 'Zone', 'Profession', 'Product_Category', 'Orders', 'Amount'],
#       dtype='object')

# %%
#check for null values
pd.isnull(df).sum()
# Out:
# User_ID             12
# Cust_name           12
# Product_ID          12
# Age                 12
# Age Group           12
# Gender              12
# State               12
# Zone                12
# Profession          12
# Product_Category    12
# Orders              12
# Amount              12
# dtype: int64

# %%
# drop null values
df.dropna(how='all', inplace=True)

# %%
df.shape
# Out:
# (11245, 12)

# %%
#replace value of Gender Column
df['Gender'] = df['Gender'].replace('M', 'Male')

# %%
#View only Male Gender data
df[df['Gender'] == 'Male']
# Out:
#          User_ID    Cust_name Product_ID   Age Age Group Gender  \
# 3      1001425.0     Virendra  P00237842  16.0      0-17   Male
# 4      1000588.0       Vishal  P00057942  28.0     26-35   Male
# 5      1000588.0       Suuraj  P00057942  28.0     26-35   Male
# 8      1003224.0       Kushal  P00205642  35.0     26-35   Male
# 11     1003829.0        Harsh  P00200842  34.0     26-35   Male
# ...          ...          ...        ...   ...       ...    ...
# 11249  1005446.0      Sheetal  P00297742  53.0     51-55   Male
# 11250  1005446.0      Sheetal  P00297742  53.0     51-55   Male
# 11252  1000695.0      Manning  P00296942  19.0     18-25   Male
# 11253  1004089.0  Reichenbach  P00171342  33.0     26-35   Male
# 11255  1004023.0       Noonan  P00059442  37.0     36-45   Male
#
#                   State      Zone       Profession Product_Category  Orders  \
# 3             Karnataka     South     Construction         Clothing     6.0
# 4               Gujarat      West  Food Processing      Electronics     4.0
# 5      Himachal Pradesh  Northern  Food Processing      Electronics     3.0
# 8         Uttar Pradesh   Central             Govt           Beauty     4.0
# 11                Delhi   Central          Banking           Health     2.0
# ...                 ...       ...              ...              ...     ...
# 11249           Gujarat      West       Healthcare           Health     3.0
# 11250    Madhya Pradesh   Central       Healthcare           Health     2.0
# 11252       Maharashtra      West         Chemical           Health     1.0
# 11253           Haryana  Northern       Healthcare           Health     5.0
# 11255         Karnataka     South      Agriculture         Clothing     4.0
#
#         Amount
# 3      23500.0
# 4      23870.0
# 5      23860.0
# 8      23809.0
# 11     23770.0
# ...        ...
# 11249    382.0
# 11250    382.0
# 11252    370.0
# 11253    367.0
# 11255    206.0
#
# [3408 rows x 12 columns]

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
df.describe()
# Out:
#             User_ID           Age        Orders        Amount
# count  1.124500e+04  11245.000000  11245.000000  11245.000000
# mean   1.003004e+06     35.415651      3.500311   9461.934237
# std    1.716207e+03     12.756369      1.713706   5234.426634
# min    1.000001e+06     12.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000      2.000000   5443.000000
# 50%    1.003065e+06     33.000000      4.000000   8109.000000
# 75%    1.004429e+06     43.000000      5.000000  12683.000000
# max    1.006040e+06     92.000000      6.000000  29350.000000

# %% [markdown]
# Total Transactions count by Gender Wise show in Bar Chart

# %%
#Total Transactions Count by Gender wise
gender_counts = df['Gender'].value_counts()
print(gender_counts)
# Out:
# Gender
# Female    7837
# Male      3408
# Name: count, dtype: int64

# %%
gender_counts = df['Gender'].value_counts().reset_index()
gender_counts.columns = ['Gender', 'Count']
# Interactive Bar
fig = px.bar(
    gender_counts, x='Gender', y='Count',
    color='Gender', color_discrete_sequence=custom_palette,
    text='Count', title='Gender Distribution'
)
fig.update_traces(textfont_size=16)
fig.update_layout(font=dict(size=16), title_font=dict(size=24))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="60b0ce32-c104-4c6f-924d-a8f31afb7658" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60b0ce32-c104-4c6f-924d-a8f31afb7658")) {                    Plotly.newPlot(                        "60b0ce32-c104-4c6f-924d-a8f31afb7658",                        [{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"text":[7837.0],"textposition":"auto","x":["Female"],"xaxis":"x","y":[7837],"yaxis":"y","type":"bar","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"Male","offsetgroup":"Male","orientation":"v","showlegend":true,"text":[3408.0],"textposition":"auto","x":["Male"],"xaxis":"x","y":[3408],"yaxis":"y","type":"bar","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"c ...

# %% [markdown]
# *Conclusion : Females do more transactions than males.*

# %% [markdown]
# Gender wise distribution in Pie Chart

# %%
gender_counts = df['Gender'].value_counts().reset_index()
gender_counts.columns = ['Gender', 'Count']
# Interactive Pie
fig = px.pie(
    gender_counts, values='Count', names='Gender',
    color='Gender', color_discrete_sequence=custom_palette,
    title='Gender Distribution (Pie Chart)',
    hole=0.4
)
fig.update_traces(textinfo='percent+label', textfont_size=16)
fig.update_layout(font=dict(size=16), title_font=dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0750c8f6-0f84-4d59-a8fc-bc8599cbd86e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0750c8f6-0f84-4d59-a8fc-bc8599cbd86e")) {                    Plotly.newPlot(                        "0750c8f6-0f84-4d59-a8fc-bc8599cbd86e",                        [{"customdata":[["Female"],["Male"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"Gender=%{customdata[0]}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Female","Male"],"legendgroup":"","marker":{"colors":["#041E42","#1B365D"]},"name":"","showlegend":true,"values":[7837,3408],"type":"pie","textfont":{"size":16},"textinfo":"percent+label"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outli ...

# %% [markdown]
# *Conclusion : Females do 38.4% more transactions than males.*

# %% [markdown]
# Gender wise Total Sales Amount show in Bar chart

# %%
df.groupby('Gender', as_index=False)['Amount'].sum()
# Out:
#    Gender       Amount
# 0  Female  74461610.49
# 1    Male  31937840.00

# %%
gen_sales = df.groupby('Gender', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
fig = px.bar(
    gen_sales, x='Gender', y='Amount',
    color='Gender', color_discrete_sequence=custom_palette,
    text='Amount', title='Gender-wise Total Sales Amount'
)
fig.update_traces(texttemplate='%{text:.0f}', textposition='outside')
fig.update_layout(font=dict(size=16), title_font=dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0771f39f-1de1-42ec-ae0b-d7b9a9e7cb74" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0771f39f-1de1-42ec-ae0b-d7b9a9e7cb74")) {                    Plotly.newPlot(                        "0771f39f-1de1-42ec-ae0b-d7b9a9e7cb74",                        [{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"text":[74461610.49],"textposition":"outside","x":["Female"],"xaxis":"x","y":[74461610.49],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"
\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"36-45","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"36-45","offsetgroup":"36-45","orientation":"v","showlegend":true,"text":[22165593.99],"textposition":"outside","x":["36-45"],"xaxis":"x","y":[22165593.99],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Age Group=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"18-25","marker":{"color":"#4B6FA5","pattern":{"shape":""}},"name":"18-25","offsetgroup":"18-25","orientation":"v","showlegend":true,"text":[17240732.0],"textposition":"outside","x":["18-25"],"xaxis":"x","y":[17240732.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Age Group=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"46-50","marker":{"color":"#7DA0CA","pattern":{"shape":""}},"name":"46-50","offsetgroup":"46-50","orientation":"v","showlegend":true,"text":[9303400.0],"textposition":"outside","x":["46-50"],"xaxis":"x","y":[9303400.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Age Group=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"51-55","marker":{"color":"#A7C7E7","pattern":{"shape":""}},"name":"51-55","offsetgroup":"51-55","orientation":"v","showlegend":true,"text":[8261477.0],"textposition":"outside","x":["51-55"],"xaxis":"x","y":[8261477.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Age Group=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"55+","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"55+","offsetgroup":"55+","orientation":"v","showlegend":true,"text":[4106987.0],"textposition":"outside","x":["55+"],"xaxis":"x","y":[4106987.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Age Group=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0-17","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"0-17","offsetgroup":"0-17","orientation":"v","showlegend":true,"text":[2728591.0],"textposition":"outside","x":["0-17"],"xaxis":"x","y":[2728591.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histo ...

# %% [markdown]
# Top 5 States by Orders

# %%
order_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(5)
print(order_state)
# Out:
#              State  Orders
# 14   Uttar Pradesh  6669.0
# 10     Maharashtra  5328.0
# 7        Karnataka  4506.0
# 2            Delhi  3893.0
# 9   Madhya Pradesh  3217.0

# %%
order_state = df.groupby('State', as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(5)
fig = px.bar(
    order_state, x='State', y='Orders',
    color='State', color_discrete_sequence=custom_palette,
    text='Orders', title='Top 5 States by Orders'
)
fig.update_traces(texttemplate='%{text:.0f}', textposition='outside')
fig.update_layout(font=dict(size=16), title_font=dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f64a6c1d-693d-4496-9c53-135b5f372493" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f64a6c1d-693d-4496-9c53-135b5f372493")) {                    Plotly.newPlot(                        "f64a6c1d-693d-4496-9c53-135b5f372493",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Uttar Pradesh","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"Uttar Pradesh","offsetgroup":"Uttar Pradesh","orientation":"v","showlegend":true,"text":[6669.0],"textposition":"outside","x":["Uttar Pradesh"],"xaxis":"x","y":[6669.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Maharashtra","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"Maharashtra","offsetgroup":"Maharashtra","orientation":"v","showlegend":true,"text":[5328.0],"textposition":"outside","x":["Maharashtra"],"xaxis":"x","y":[5328.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Karnataka","marker":{"color":"#4B6FA5","pattern":{"shape":""}},"name":"Karnataka","offsetgroup":"Karnataka","orientation":"v","showlegend":true,"text":[4506.0],"textposition":"outside","x":["Karnataka"],"xaxis":"x","y":[4506.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#7DA0CA","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"text":[3893.0],"textposition":"outside","x":["Delhi"],"xaxis":"x","y":[3893.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Madhya Pradesh","marker":{"color":"#A7C7E7","pattern":{"shape":""}},"name":"Madhya Pradesh","offsetgroup":"Madhya Pradesh","orientation":"v","showlegend":true,"text":[3217.0],"textposition":"outside","x":["Madhya Pradesh"],"xaxis":"x","y":[3217.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outline ...

# %% [markdown]
# Top 5 States by Sales Amount

# %%
sales_state = df.groupby('State', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(5)
fig = px.bar(
    sales_state, x='State', y='Amount',
    color='State', color_discrete_sequence=custom_palette,
    text='Amount', title='Top 5 States by Sales Amount'
)
fig.update_traces(texttemplate='%{text:.0f}', textposition='outside')
fig.update_layout(font=dict(size=16), title_font=dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6829666d-e864-4f22-960c-51fc54f0cf69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6829666d-e864-4f22-960c-51fc54f0cf69")) {                    Plotly.newPlot(                        "6829666d-e864-4f22-960c-51fc54f0cf69",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Uttar Pradesh","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"Uttar Pradesh","offsetgroup":"Uttar Pradesh","orientation":"v","showlegend":true,"text":[19380394.0],"textposition":"outside","x":["Uttar Pradesh"],"xaxis":"x","y":[19380394.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Maharashtra","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"Maharashtra","offsetgroup":"Maharashtra","orientation":"v","showlegend":true,"text":[14450091.0],"textposition":"outside","x":["Maharashtra"],"xaxis":"x","y":[14450091.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Karnataka","marker":{"color":"#4B6FA5","pattern":{"shape":""}},"name":"Karnataka","offsetgroup":"Karnataka","orientation":"v","showlegend":true,"text":[13543778.0],"textposition":"outside","x":["Karnataka"],"xaxis":"x","y":[13543778.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#7DA0CA","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"text":[11645323.5],"textposition":"outside","x":["Delhi"],"xaxis":"x","y":[11645323.5],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"State=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Madhya Pradesh","marker":{"color":"#A7C7E7","pattern":{"shape":""}},"name":"Madhya Pradesh","offsetgroup":"Madhya Pradesh","orientation":"v","showlegend":true,"text":[8126142.0],"textposition":"outside","x":["Madhya Pradesh"],"xaxis":"x","y":[8126142.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{" ...

# %% [markdown]
# *From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [markdown]
# Product Category Analysis

# %%
cat_counts = df['Product_Category'].value_counts().reset_index()
cat_counts.columns = ['Product_Category', 'Count']
fig = px.bar(
    cat_counts, x='Product_Category', y='Count',
    color='Product_Category', color_discrete_sequence=custom_palette,
    text='Count', title='Product Category-wise Transactions'
)
fig.update_traces(texttemplate='%{text:.0f}', textposition='outside')
fig.update_layout(font=dict(size=16), title_font=dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="021d73a3-0003-467e-98c8-ff79961c99ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("021d73a3-0003-467e-98c8-ff79961c99ea")) {                    Plotly.newPlot(                        "021d73a3-0003-467e-98c8-ff79961c99ea",                        [{"alignmentgroup":"True","hovertemplate":"Product_Category=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beauty","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"Beauty","offsetgroup":"Beauty","orientation":"v","showlegend":true,"text":[2333.0],"textposition":"outside","x":["Beauty"],"xaxis":"x","y":[2333],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_Category=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sports ","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"Sports ","offsetgroup":"Sports ","orientation":"v","showlegend":true,"text":[2276.0],"textposition":"outside","x":["Sports "],"xaxis":"x","y":[2276],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_Category=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electronics","marker":{"color":"#4B6FA5","pattern":{"shape":""}},"name":"Electronics","offsetgroup":"Electronics","orientation":"v","showlegend":true,"text":[2235.0],"textposition":"outside","x":["Electronics"],"xaxis":"x","y":[2235],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_Category=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health","marker":{"color":"#7DA0CA","pattern":{"shape":""}},"name":"Health","offsetgroup":"Health","orientation":"v","showlegend":true,"text":[2222.0],"textposition":"outside","x":["Health"],"xaxis":"x","y":[2222],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_Category=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clothing","marker":{"color":"#A7C7E7","pattern":{"shape":""}},"name":"Clothing","offsetgroup":"Clothing","orientation":"v","showlegend":true,"text":[2179.0],"textposition":"outside","x":["Clothing"],"xaxis":"x","y":[2179],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks" ...

# %% [markdown]
# *Conclusion : Product category Beauty has most transactions.*

# %% [markdown]
# Amount by Product Category (Top 5)

# %%
sales_cat = df.groupby('Product_Category', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(5)
fig = px.bar(
    sales_cat, x='Product_Category', y='Amount',
    color='Product_Category', color_discrete_sequence=custom_palette,
    text='Amount', title='Top 5 Product Categories by Sales Amount'
)
fig.update_traces(texttemplate='%{text:.0f}', textposition='outside')
fig.update_layout(font=dict(size=16), title_font=dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d1b749eb-7eee-471d-bacc-9c1444d36b57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1b749eb-7eee-471d-bacc-9c1444d36b57")) {                    Plotly.newPlot(                        "d1b749eb-7eee-471d-bacc-9c1444d36b57",                        [{"alignmentgroup":"True","hovertemplate":"Product_Category=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beauty","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"Beauty","offsetgroup":"Beauty","orientation":"v","showlegend":true,"text":[22471834.99],"textposition":"outside","x":["Beauty"],"xaxis":"x","y":[22471834.99],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_Category=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sports ","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"Sports ","offsetgroup":"Sports ","orientation":"v","showlegend":true,"text":[21391462.0],"textposition":"outside","x":["Sports "],"xaxis":"x","y":[21391462.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_Category=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electronics","marker":{"color":"#4B6FA5","pattern":{"shape":""}},"name":"Electronics","offsetgroup":"Electronics","orientation":"v","showlegend":true,"text":[21160743.0],"textposition":"outside","x":["Electronics"],"xaxis":"x","y":[21160743.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_Category=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Clothing","marker":{"color":"#7DA0CA","pattern":{"shape":""}},"name":"Clothing","offsetgroup":"Clothing","orientation":"v","showlegend":true,"text":[20833093.5],"textposition":"outside","x":["Clothing"],"xaxis":"x","y":[20833093.5],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_Category=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Health","marker":{"color":"#A7C7E7","pattern":{"shape":""}},"name":"Health","offsetgroup":"Health","orientation":"v","showlegend":true,"text":[20542317.0],"textposition":"outside","x":["Health"],"xaxis":"x","y":[20542317.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl": ...

# %% [markdown]
# Product Category and Gender-wise Sales

# %%
sales_pro = df.groupby(['Product_Category', 'Gender'], as_index=False)['Amount'].sum()
fig = px.bar(
    sales_pro, x='Product_Category', y='Amount', color='Gender',
    barmode='group', color_discrete_sequence=custom_palette,
    text='Amount', title='Product Category and Gender-wise Sales'
)
fig.update_traces(texttemplate='%{text:.0f}', textposition='outside')
fig.update_layout(font=dict(size=16), title_font=dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ee3e06f-fba4-4329-8c6d-e1d0281a84d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ee3e06f-fba4-4329-8c6d-e1d0281a84d7")) {                    Plotly.newPlot(                        "0ee3e06f-fba4-4329-8c6d-e1d0281a84d7",                        [{"alignmentgroup":"True","hovertemplate":"Gender=Female\u003cbr\u003eProduct_Category=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":true,"text":[15707866.99,14836544.5,14825544.0,14480570.0,14611085.0],"textposition":"outside","x":["Beauty","Clothing","Electronics","Health","Sports "],"xaxis":"x","y":[15707866.99,14836544.5,14825544.0,14480570.0,14611085.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Gender=Male\u003cbr\u003eProduct_Category=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"Male","offsetgroup":"Male","orientation":"v","showlegend":true,"text":[6763968.0,5996549.0,6335199.0,6061747.0,6780377.0],"textposition":"outside","x":["Beauty","Clothing","Electronics","Health","Sports "],"xaxis":"x","y":[6763968.0,5996549.0,6335199.0,6061747.0,6780377.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444 ...

# %% [markdown]
# *From above graphs we can see that most of the buyers are Female

# %% [markdown]
# Profession Analysis

# %%
prof_counts = df['Profession'].value_counts().reset_index()
prof_counts.columns = ['Profession', 'Count']
fig = px.bar(
    prof_counts, x='Profession', y='Count',
    color='Profession', color_discrete_sequence=custom_palette,
    text='Count', title='Profession-wise Transactions'
)
fig.update_traces(texttemplate='%{text:.0f}', textposition='outside')
fig.update_layout(font=dict(size=16), title_font=dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="371c8206-1bdf-4ca5-b315-bc523fab56f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("371c8206-1bdf-4ca5-b315-bc523fab56f8")) {                    Plotly.newPlot(                        "371c8206-1bdf-4ca5-b315-bc523fab56f8",                        [{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IT Sector","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"IT Sector","offsetgroup":"IT Sector","orientation":"v","showlegend":true,"text":[1586.0],"textposition":"outside","x":["IT Sector"],"xaxis":"x","y":[1586],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Healthcare","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"Healthcare","offsetgroup":"Healthcare","orientation":"v","showlegend":true,"text":[1408.0],"textposition":"outside","x":["Healthcare"],"xaxis":"x","y":[1408],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aviation","marker":{"color":"#4B6FA5","pattern":{"shape":""}},"name":"Aviation","offsetgroup":"Aviation","orientation":"v","showlegend":true,"text":[1310.0],"textposition":"outside","x":["Aviation"],"xaxis":"x","y":[1310],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Banking","marker":{"color":"#7DA0CA","pattern":{"shape":""}},"name":"Banking","offsetgroup":"Banking","orientation":"v","showlegend":true,"text":[1139.0],"textposition":"outside","x":["Banking"],"xaxis":"x","y":[1139],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Govt","marker":{"color":"#A7C7E7","pattern":{"shape":""}},"name":"Govt","offsetgroup":"Govt","orientation":"v","showlegend":true,"text":[854.0],"textposition":"outside","x":["Govt"],"xaxis":"x","y":[854],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hospitality","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"Hospitality","offsetgroup":"Hospitality","orientation":"v","showlegend":true,"text":[704.0],"textposition":"outside","x":["Hospitality"],"xaxis":"x","y":[704],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Media","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"Media","offsetgroup":"Media","orientation":"v","showlegend":true,"text":[637.0],"textposition":"outside","x":["Media"],"xaxis":"x","y":[637],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Automobile","marker":{"color":"#4B6FA5","pattern":{"shape":""}},"name":"Automobile","offsetgroup":"Automobile","orientation":"v","showlegend":true,"text":[565.0],"textposition":"outside","x":["Automobile"],"xaxis":"x","y":[565],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003 ...

# %% [markdown]
# *Conclusion : IT professionals perform the most transactions*

# %% [markdown]
# Top 3 Professions by Sales

# %%
sales_prof = df.groupby('Profession', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(3)
fig = px.bar(
    sales_prof, x='Profession', y='Amount',
    color='Profession', color_discrete_sequence=custom_palette,
    text='Amount', title='Top 3 Professions by Sales Amount'
)
fig.update_traces(texttemplate='%{text:.0f}', textposition='outside')
fig.update_layout(font=dict(size=16), title_font=dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e11bae4d-5351-4079-ae5c-3087fd7cc511" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e11bae4d-5351-4079-ae5c-3087fd7cc511")) {                    Plotly.newPlot(                        "e11bae4d-5351-4079-ae5c-3087fd7cc511",                        [{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"IT Sector","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"IT Sector","offsetgroup":"IT Sector","orientation":"v","showlegend":true,"text":[14830979.0],"textposition":"outside","x":["IT Sector"],"xaxis":"x","y":[14830979.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Healthcare","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"Healthcare","offsetgroup":"Healthcare","orientation":"v","showlegend":true,"text":[13031135.49],"textposition":"outside","x":["Healthcare"],"xaxis":"x","y":[13031135.49],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Profession=%{x}\u003cbr\u003eAmount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aviation","marker":{"color":"#4B6FA5","pattern":{"shape":""}},"name":"Aviation","offsetgroup":"Aviation","orientation":"v","showlegend":true,"text":[12602298.0],"textposition":"outside","x":["Aviation"],"xaxis":"x","y":[12602298.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0, ...

# %% [markdown]
# *From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector*

# %% [markdown]
# Top 10 Products by Orders

# %%
top_products = df.groupby('Product_ID', as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
fig = px.bar(
    top_products, x='Product_ID', y='Orders',
    color='Product_ID', color_discrete_sequence=custom_palette,
    text='Orders', title='Top 10 Products by Orders'
)
fig.update_traces(texttemplate='%{text:.0f}', textposition='outside')
fig.update_layout(font=dict(size=16), title_font=dict(size=20))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4e046d06-7b0a-4c97-84db-b6f13c6dad95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e046d06-7b0a-4c97-84db-b6f13c6dad95")) {                    Plotly.newPlot(                        "4e046d06-7b0a-4c97-84db-b6f13c6dad95",                        [{"alignmentgroup":"True","hovertemplate":"Product_ID=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P00265242","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"P00265242","offsetgroup":"P00265242","orientation":"v","showlegend":true,"text":[187.0],"textposition":"outside","x":["P00265242"],"xaxis":"x","y":[187.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_ID=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P00110942","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"P00110942","offsetgroup":"P00110942","orientation":"v","showlegend":true,"text":[149.0],"textposition":"outside","x":["P00110942"],"xaxis":"x","y":[149.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_ID=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P00184942","marker":{"color":"#4B6FA5","pattern":{"shape":""}},"name":"P00184942","offsetgroup":"P00184942","orientation":"v","showlegend":true,"text":[126.0],"textposition":"outside","x":["P00184942"],"xaxis":"x","y":[126.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_ID=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P00114942","marker":{"color":"#7DA0CA","pattern":{"shape":""}},"name":"P00114942","offsetgroup":"P00114942","orientation":"v","showlegend":true,"text":[123.0],"textposition":"outside","x":["P00114942"],"xaxis":"x","y":[123.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_ID=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P00112142","marker":{"color":"#A7C7E7","pattern":{"shape":""}},"name":"P00112142","offsetgroup":"P00112142","orientation":"v","showlegend":true,"text":[119.0],"textposition":"outside","x":["P00112142"],"xaxis":"x","y":[119.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_ID=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P00237542","marker":{"color":"#041E42","pattern":{"shape":""}},"name":"P00237542","offsetgroup":"P00237542","orientation":"v","showlegend":true,"text":[114.0],"textposition":"outside","x":["P00237542"],"xaxis":"x","y":[114.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_ID=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P00059442","marker":{"color":"#1B365D","pattern":{"shape":""}},"name":"P00059442","offsetgroup":"P00059442","orientation":"v","showlegend":true,"text":[107.0],"textposition":"outside","x":["P00059442"],"xaxis":"x","y":[107.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_ID=%{x}\u003cbr\u003eOrders=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P00145042","marker":{"color":"#4B6FA5","pattern":{"shape":""}},"name":"P00145042","offsetgroup":"P00145042","orientation":"v","showlegend":true,"text":[107.0],"textposition":"outside","x":["P00145042"],"xaxis":"x","y":[107.0],"yaxis":"y","type":"bar","texttemplate":"%{text:.0f}"},{"alignmentgroup":"True","hovertemplate":"Product_ID ...

# %% [markdown]
# ## Conclusion:
#
# ### *Female age group 26-35 yrs from Uttar Pradesh,  Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Beauty, Sports and Electronics*
